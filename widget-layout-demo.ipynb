# %%
import altair as alt
import ipywidgets as ipw
import pandas as pd

from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

# %%
iris = data.iris()

# %%
species = list(iris.species.unique())
species
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
species_radio_buttons = ipw.RadioButtons(
    options=species,
    value='setosa',
    description='Species:',
    disabled=False
)
species_radio_buttons
# Out:
# RadioButtons(description='Species:', options=('setosa', 'versicolor', 'virginica'), value='setosa')

# %%
alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)
